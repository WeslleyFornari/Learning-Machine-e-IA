# %%
# !pip -q install plotly
# Out:
# 'pip' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %%
# !pip -q install yellowbrick
# Out:
# 'pip' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
import pickle
with open('base_dados/census.pkl', 'rb') as f:
  X_credit_treinamento, y_credit_treinamento, X_credit_teste, y_credit_teste = pickle.load(f)

# %%
with open('base_dados/credit.pkl', 'rb') as h:
  X_credit_treinamento, y_credit_treinamento, X_credit_teste, y_credit_teste = pickle.load(h)

# %%
# X - pre processamento (quant, colunas) Y- classes

X_credit_treinamento.shape, y_credit_treinamento.shape
# Out:
# ((1500, 3), (1500,))
